# %%
import pandas as pd
import numpy as np

# %%
pip list --format=freeze > requirements.txt

# %%
from pycaret.datasets import get_data
from pycaret.regression import *

# %%
# df_finance = pd.read_csv('finance.csv')

# %%
data = get_data("diamond")
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
s = setup(data, target="Price", session_id=123)
# Out:
# <style type="text/css">
# #T_c7d25_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c7d25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7d25_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c7d25_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7d25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7d25_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c7d25_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7d25_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c7d25_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7d25_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_c7d25_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7d25_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_c7d25_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7d25_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_c7d25_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7d25_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_c7d25_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7d25_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_c7d25_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c7d25_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_c7d25_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c7d25_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_c7d25_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c7d25_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_c7d25_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c7d25_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_c7d25_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c7d25_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_c7d25_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c7d25_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_c7d25_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c7d25_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_c7d25_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c7d25_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_c7d25_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c7d25_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_c7d25_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c7d25_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_c7d25_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c7d25_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_c7d25_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c7d25_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_c7d25_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c7d25_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_c7d25_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_c7d25_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_c7d25_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_c7d25_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_c7d25_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_c7d25_row21_col1" class="data row21 col1" >a47a</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_0aab0 th {
#   text-align: left;
# }
# #T_0aab0_row0_col0, #T_0aab0_row0_col5, #T_0aab0_row0_col6, #T_0aab0_row1_col0, #T_0aab0_row1_col1, #T_0aab0_row1_col2, #T_0aab0_row1_col3, #T_0aab0_row1_col4, #T_0aab0_row1_col5, #T_0aab0_row1_col6, #T_0aab0_row2_col0, #T_0aab0_row2_col1, #T_0aab0_row2_col2, #T_0aab0_row2_col3, #T_0aab0_row2_col4, #T_0aab0_row3_col0, #T_0aab0_row3_col1, #T_0aab0_row3_col2, #T_0aab0_row3_col3, #T_0aab0_row3_col4, #T_0aab0_row3_col5, #T_0aab0_row3_col6, #T_0aab0_row4_col0, #T_0aab0_row4_col1, #T_0aab0_row4_col2, #T_0aab0_row4_col3, #T_0aab0_row4_col4, #T_0aab0_row4_col5, #T_0aab0_row4_col6, #T_0aab0_row5_col0, #T_0aab0_row5_col1, #T_0aab0_row5_col2, #T_0aab0_row5_col3, #T_0aab0_row5_col4, #T_0aab0_row5_col5, #T_0aab0_row5_col6, #T_0aab0_row6_col0, #T_0aab0_row6_col1, #T_0aab0_row6_col2, #T_0aab0_row6_col3, #T_0aab0_row6_col4, #T_0aab0_row6_col5, #T_0aab0_row6_col6, #T_0aab0_row7_col0, #T_0aab0_row7_col1, #T_0aab0_row7_col2, #T_0aab0_row7_col3, #T_0aab0_row7_col4, #T_0aab0_row7_col5, #T_0aab0_row7_col6, #T_0aab0_row8_col0, #T_0aab0_row8_col1, #T_0aab0_row8_col2, #T_0aab0_row8_col3, #T_0aab0_row8_col4, #T_0aab0_row8_col5, #T_0aab0_row8_col6, #T_0aab0_row9_col0, #T_0aab0_row9_col1, #T_0aab0_row9_col2, #T_0aab0_row9_col3, #T_0aab0_row9_col4, #T_0aab0_row9_col5, #T_0aab0_row9_col6, #T_0aab0_row10_col0, #T_0aab0_row10_col1, #T_0aab0_row10_col2, #T_0aab0_row10_col3, #T_0aab0_row10_col4, #T_0aab0_row10_col5, #T_0aab0_row10_col6, #T_0aab0_row11_col0, #T_0aab0_row11_col1, #T_0aab0_row11_col2, #T_0aab0_row11_col3, #T_0aab0_row11_col4, #T_0aab0_row11_col5, #T_0aab0_row11_col6, #T_0aab0_row12_col0, #T_0aab0_row12_col1, #T_0aab0_row12_col2, #T_0aab0_row12_col3, #T_0aab0_row12_col4, #T_0aab0_row12_col5, #T_0aab0_row12_col6, #T_0aab0_row13_col0, #T_0aab0_row13_col1, #T_0aab0_row13_col2, #T_0aab0_row13_col3, #T_0aab0_row13_col4, #T_0aab0_row13_col5, #T_0aab0_row13_col6, #T_0aab0_row14_col0, #T_0aab0_row14_col1, #T_0aab0_row14_col2, #T_0aab0_row14_col3, #T_0aab0_row14_col4, #T_0aab0_row14_col5, #T_0aab0_row14_col6, #T_0aab0_row15_col0, #T_0aab0_row15_col1, #T_0aab0_row15_col2, #T_0aab0_row15_col3, #T_0aab0_row15_col4, #T_0aab0_row15_col5, #T_0aab0_row15_col6, #T_0aab0_row16_col0, #T_0aab0_row16_col1, #T_0aab0_row16_col2, #T_0aab0_row16_col3, #T_0aab0_row16_col4, #T_0aab0_row16_col5, #T_0aab0_row16_col6, #T_0aab0_row17_col0, #T_0aab0_row17_col1, #T_0aab0_row17_col2, #T_0aab0_row17_col3, #T_0aab0_row17_col4, #T_0aab0_row17_col5, #T_0aab0_row17_col6 {
#   text-align: left;
# }
# #T_0aab0_row0_col1, #T_0aab0_row0_col2, #T_0aab0_row0_col3, #T_0aab0_row0_col4, #T_0aab0_row2_col5, #T_0aab0_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_0aab0_row0_col7, #T_0aab0_row1_col7, #T_0aab0_row2_col7, #T_0aab0_row3_col7, #T_0aab0_row4_col7, #T_0aab0_row5_col7, #T_0aab0_row6_col7, #T_0aab0_row7_col7, #T_0aab0_row8_col7, #T_0aab0_row9_col7, #T_0aab0_row10_col7, #T_0aab0_row11_col7, #T_0aab0_row13_col7, #T_0aab0_row14_col7, #T_0aab0_row15_col7, #T_0aab0_row16_col7, #T_0aab0_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_0aab0_row12_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_0aab0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aab0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0aab0_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0aab0_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0aab0_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0aab0_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0aab0_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0aab0_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_0aab0_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aab0_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_0aab0_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_0aab0_row0_col1" class="data row0 col1" >719.6871</td>
#       <td id="T_0aab0_row0_col2" class="data row0 col2" >2033874.0284</td>
#       <td id="T_0aab0_row0_col3" class="data row0 col3" >1390.8879</td>
#       <td id="T_0aab0_row0_col4" class="data row0 col4" >0.9809</td>
#       <td id="T_0aab0_row0_col5" class="data row0 col5" >0.0786</td>
#       <td id="T_0aab0_row0_col6" class="data row0 col6" >0.0585</td>
#       <td id="T_0aab0_row0_col7" class="data row0 col7" >0.2200</td>
#     </tr>
#     <tr>
#       <th id="T_0aab0_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_0aab0_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_0aab0_row1_col1" class="data row1 col1" >725.2299</td>
#       <td id="T_0aab0_row1_col2" class="data row1 col2" >2336386.4997</td>
#       <td id="T_0aab0_row1_col3" class="data row1 col3" >1491.5615</td>
#       <td id="T_0aab0_row1_col4" class="data row1 col4" >0.9781</td>
#       <td id="T_0aab0_row1_col5" class="data row1 col5" >0.0785</td>
#       <td id="T_0aab0_row1_col6" class="data row1 col6" >0.0577</td>
#       <td id="T_0aab0_row1_col7" class="data row1 col7" >0.2320</td>
#     </tr>
#     <tr>
#       <th id="T_0aab0_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_0aab0_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_0aab0_row2_col1" class="data row2 col1" >721.5692</td>
#       <td id="T_0aab0_row2_col2" class="data row2 col2" >2747712.1060</td>
#       <td id="T_0aab0_row2_col3" class="data row2 col3" >1593.0198</td>
#       <td id="T_0aab0_row2_col4" class="data row2 col4" >0.9748</td>
#       <td id="T_0aab0_row2_col5" class="data row2 col5" >0.0750</td>
#       <td id="T_0aab0_row2_col6" class="data row2 col6" >0.0551</td>
#       <td id="T_0aab0_row2_col7" class="data row2 col7" >1.1480</td>
#     </tr>
#     <tr>
#       <th id="T_0aab0_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_0aab0_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0aab0_row3_col1" class="data row3 col1" >870.4619</td>
#       <td id="T_0aab0_row3_col2" class="data row3 col2" >2677900.4116</td>
#       <td id="T_0aab0_row3_col3" class="data row3 col3" >1616.3756</td>
#       <td id="T_0aab0_row3_col4" class="data row3 col4" >0.9744</td>
#       <td id="T_0aab0_row3_col5" class="data row3 col5" >0.0990</td>
#       <td id="T_0aab0_row3_col6" class="data row3 col6" >0.0750</td>
#       <td id="T_0aab0_row3_col7" class="data row3 col7" >0.0750</td>
#     </tr>
#     <tr>
#       <th id="T_0aab0_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_0aab0_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_0aab0_row4_col1" class="data row4 col1" >919.7628</td>
#       <td id="T_0aab0_row4_col2" class="data row4 col2" >3495425.3910</td>
#       <td id="T_0aab0_row4_col3" class="data row4 col3" >1821.5832</td>
#       <td id="T_0aab0_row4_col4" class="data row4 col4" >0.9664</td>
#       <td id="T_0aab0_row4_col5" class="data row4 col5" >0.1025</td>
#       <td id="T_0aab0_row4_col6" class="data row4 col6" >0.0744</td>
#       <td id="T_0aab0_row4_col7" class="data row4 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_0aab0_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_0aab0_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_0aab0_row5_col1" class="data row5 col1" >2491.2859</td>
#       <td id="T_0aab0_row5_col2" class="data row5 col2" >14957594.1466</td>
#       <td id="T_0aab0_row5_col3" class="data row5 col3" >3840.8633</td>
#       <td id="T_0aab0_row5_col4" class="data row5 col4" >0.8568</td>
#       <td id="T_0aab0_row5_col5" class="data row5 col5" >0.6470</td>
#       <td id="T_0aab0_row5_col6" class="data row5 col6" >0.2966</td>
#       <td id="T_0aab0_row5_col7" class="data row5
